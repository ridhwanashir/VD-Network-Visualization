# %% [markdown]
# # Import Library Networkx
# Ridhwan Nashir 1301184259
#
# IF 42-01
# Visualisasi Data

# %%
import networkx as nx
import matplotlib.pyplot as plt
# G.add_nodes_from(['Cimahi','Bandung','Soreang','Garut','Sumedang','Subang','Sukabumi','Bogor',
# 'Cianjur','Bekasi','Karawang','Purwakarta','Indramayu','Cirebon','Kuningan','Sumber','Majalengka','Ciamis','Tasikmalaya','Depok','Cibinong'])
# G.nodes()

# %% [markdown]
# # Input Data
# Add edge, node, weight, dan length

# %%
G = nx.Graph()
G.add_edge('Sukabumi', 'Bogor', weight=100/61, length=61)
G.add_edge('Sukabumi', 'Cianjur', weight=100/32, length=32)
G.add_edge('Cianjur', 'Cimahi', weight=100/65, length=65)
G.add_edge('Cianjur', 'Purwakarta', weight=100/99, length=99)
G.add_edge('Cianjur', 'Bogor', weight=100/74, length=74)
G.add_edge('Bogor', 'Depok', weight=100/44, length=44)
G.add_edge('Depok', 'Bekasi', weight=100/44, length=44)
G.add_edge('Bekasi', 'Karawang', weight=100/55, length=55)
G.add_edge('Karawang', 'Purwakarta', weight=100/34, length=34)
G.add_edge('Karawang', 'Indramayu', weight=100/127, length=127)
G.add_edge('Karawang', 'Subang', weight=100/66, length=66)
G.add_edge('Purwakarta', 'Subang', weight=100/56, length=56)
G.add_edge('Purwakarta', 'Cimahi', weight=100/124, length=124)
G.add_edge('Purwakarta', 'Indramayu', weight=100/125, length=125)
G.add_edge('Cimahi', 'Bandung', weight=100/14, length=14)
G.add_edge('Bandung', 'Soreang', weight=100/20, length=20)
G.add_edge('Bandung', 'Subang', weight=100/52, length=52)
G.add_edge('Bandung', 'Sumedang', weight=100/45, length=45)
G.add_edge('Bandung', 'Garut', weight=100/63, length=63)
G.add_edge('Bandung', 'Tasikmalaya', weight=100/45, length=106)
G.add_edge('Garut', 'Tasikmalaya', weight=100/57, length=57)
G.add_edge('Tasikmalaya', 'Ciamis', weight=100/17, length=17)
G.add_edge('Sumedang', 'Majalengka', weight=100/46, length=46)
G.add_edge('Sumedang', 'Indramayu', weight=100/139, length=139)
G.add_edge('Indramayu', 'Majalengka', weight=100/82, length=82)
G.add_edge('Indramayu', 'Cirebon', weight=100/54, length=54)
G.add_edge('Cirebon', 'Ciamis', weight=100/103, length=103)
G.add_edge('Ciamis', 'Majalengka', weight=100/88, length=88)

G.edges()
nx.draw(G, with_labels=True)
plt.show()

# %% [markdown]
# Melihat derajat centrality

# %%
nx.degree_centrality(G)
# Out:
# {'Bandung': 0.3529411764705882,
#  'Bekasi': 0.11764705882352941,
#  'Bogor': 0.1764705882352941,
#  'Ciamis': 0.1764705882352941,
#  'Cianjur': 0.23529411764705882,
#  'Cimahi': 0.1764705882352941,
#  'Cirebon': 0.11764705882352941,
#  'Depok': 0.11764705882352941,
#  'Garut': 0.11764705882352941,
#  'Indramayu': 0.29411764705882354,
#  'Karawang': 0.23529411764705882,
#  'Majalengka': 0.1764705882352941,
#  'Purwakarta': 0.29411764705882354,
#  'Soreang': 0.058823529411764705,
#  'Subang': 0.1764705882352941,
#  'Sukabumi': 0.11764705882352941,
#  'Sumedang': 0.1764705882352941,
#  'Tasikmalaya': 0.1764705882352941}
